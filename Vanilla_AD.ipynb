# %% [markdown]
# <a href="https://colab.research.google.com/github/ericzhao28/ActiveDialogue/blob/master/Vanilla_AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import comet_ml
import torch
assert torch.cuda.is_available()
torch.cuda.set_device(0)

# %%
not_run = True

# %%
import logging, sys


shared = """
        --device 0
        --seed 2
        --nick vanilla
        --dexp '/content/gdrive/My Drive/Colab Notebooks/exp'
        --stop joint_goal
        """

# %%
from ActiveDialogue.main.seed import main

main("--lr 0.001 --force_seed --seed_epochs 300 --model glad" + shared, not_run)
not_run = False
# Out:
# COMET INFO: old comet version (3.1.4) detected. current: 3.1.5 please update your comet lib with command: `pip install --no-cache-dir --upgrade comet_ml`
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/ericzhao28/activedialogue/cabc2a39673e4619a7661a4553378292
# Loading Woz dataset.
# Woz: loading split train
# Loaded 2536 turns.
# Loaded 600 dialogues.
# 94 classes
# Woz: loading split dev
# Loaded 830 turns.
# Loaded 200 dialogues.
# 94 classes
# Woz: loading split test
# Loaded 1646 turns.
# Loaded 400 dialogues.
# 94 classes
# dataset sizes: {'train': 600, 'dev': 200, 'test': 400}
# First 10 dataset stream pointers: [1155  796  970  967 1978  897 1975 2332  964  657]
# Seed size: 512
# Pool size: 2024
# loading model from /content/gdrive/My Drive/Colab Notebooks/exp/vanilla/seed2.t7
# No loaded seed. Training now.
# Running dev evaluation
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.0, 'turn_request': 0.007228915662650603, 'joint_goal': 0.0}
# Starting fit epoch 1.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.5313253012048192, 'turn_request': 0.7048192771084337, 'joint_goal': 0.0}
# Starting fit epoch 2.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.5313253012048192, 'turn_request': 0.7048192771084337, 'joint_goal': 0.0}
# Starting fit epoch 3.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.5313253012048192, 'turn_request': 0.7048192771084337, 'joint_goal': 0.0}
# Starting fit epoch 4.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.5313253012048192, 'turn_request': 0.7072289156626506, 'joint_goal': 0.0}
# Starting fit epoch 5.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.5313253012048192, 'turn_request': 0.689156626506024, 'joint_goal': 0.0}
# Starting fit epoch 6.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.5313253012048192, 'turn_request': 0.7048192771084337, 'joint_goal': 0.0}
# Starting fit epoch 7.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.5313253012048192, 'turn_request': 0.7024096385542169, 'joint_goal': 0.0}
# Starting fit epoch 8.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.5313253012048192, 'turn_request': 0.7060240963855422, 'joint_goal': 0.0}
# Starting fit epoch 9.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.5313253012048192, 'turn_request': 0.7096385542168675, 'joint_goal': 0.0}
# Starting fit epoch 10.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.5313253012048192, 'turn_request': 0.708433734939759, 'joint_goal': 0.0}
# Starting fit epoch 11.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.5325301204819277, 'turn_request': 0.7120481927710843, 'joint_goal': 0.0}
# Starting fit epoch 12.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.5325301204819277, 'turn_request': 0.7096385542168675, 'joint_goal': 0.0}
# Starting fit epoch 13.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.5421686746987951, 'turn_request': 0.7325301204819277, 'joint_goal': 0.0}
# Starting fit epoch 14.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.5325301204819277, 'turn_request': 0.7506024096385542, 'joint_goal': 0.0}
# Starting fit epoch 15.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.5325301204819277, 'turn_request': 0.7325301204819277, 'joint_goal': 0.0}
# Starting fit epoch 16.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.5349397590361445, 'turn_request': 0.7662650602409639, 'joint_goal': 0.0}
# Starting fit epoch 17.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.

# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.8240963855421687, 'turn_request': 0.9337349397590361, 'joint_goal': 0.5951807228915663}
# Starting fit epoch 285.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.8144578313253013, 'turn_request': 0.9373493975903614, 'joint_goal': 0.563855421686747}
# Starting fit epoch 286.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.8301204819277108, 'turn_request': 0.936144578313253, 'joint_goal': 0.6072289156626506}
# Saving best!
# saving model to /content/gdrive/My Drive/Colab Notebooks/exp/vanilla/seed2.t7
# Starting fit epoch 287.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.8204819277108434, 'turn_request': 0.9385542168674699, 'joint_goal': 0.5843373493975904}
# Starting fit epoch 288.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.8240963855421687, 'turn_request': 0.9397590361445783, 'joint_goal': 0.5975903614457831}
# Starting fit epoch 289.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.8060240963855422, 'turn_request': 0.946987951807229, 'joint_goal': 0.5698795180722892}
# Starting fit epoch 290.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.8216867469879519, 'turn_request': 0.9421686746987952, 'joint_goal': 0.5975903614457831}
# Starting fit epoch 291.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.8433734939759037, 'turn_request': 0.9421686746987952, 'joint_goal': 0.6289156626506024}
# Saving best!
# saving model to /content/gdrive/My Drive/Colab Notebooks/exp/vanilla/seed2.t7
# Starting fit epoch 292.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.8228915662650602, 'turn_request': 0.9421686746987952, 'joint_goal': 0.5927710843373494}
# Starting fit epoch 293.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.8216867469879519, 'turn_request': 0.9397590361445783, 'joint_goal': 0.5831325301204819}
# Starting fit epoch 294.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.8228915662650602, 'turn_request': 0.9349397590361446, 'joint_goal': 0.5831325301204819}
# Starting fit epoch 295.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.827710843373494, 'turn_request': 0.9301204819277108, 'joint_goal': 0.5963855421686747}
# Starting fit epoch 296.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.8265060240963855, 'turn_request': 0.9373493975903614, 'joint_goal': 0.6}
# Starting fit epoch 297.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.8228915662650602, 'turn_request': 0.9373493975903614, 'joint_goal': 0.5819277108433735}
# Starting fit epoch 298.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.8240963855421687, 'turn_request': 0.936144578313253, 'joint_goal': 0.5963855421686747}
# Starting fit epoch 299.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.8313253012048193, 'turn_request': 0.9337349397590361, 'joint_goal': 0.6120481927710844}
# Seed completed.
# loading model from /content/gdrive/My Drive/Colab Notebooks/exp/vanilla/seed2.t7
# Running dev evaluation
# Seed metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.8433734939759037, 'turn_request': 0.9421686746987952, 'joint_goal': 0.6289156626506024}

# %%
from ActiveDialogue.main.vanilla import main

# %%
main("--strategy bald --lr 0.001 --init_threshold 0.15 --model glad " + shared, not_run)
not_run = False
# Out:
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/ericzhao28/activedialogue/cabc2a39673e4619a7661a4553378292
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     Final seed Example label proportion  : 1
# COMET INFO:     Final seed Exhausted label budget    : 1
# COMET INFO:     Final seed Exhausted labels          : 1
# COMET INFO:     Final seed Stream progress           : 1
# COMET INFO:     Final seed joint_goal                : 0.6289156626506024
# COMET INFO:     Final seed turn_inform               : 0.8433734939759037
# COMET INFO:     Final seed turn_request              : 0.9421686746987952
# COMET INFO:     train_Example label proportion [300] : 300
# COMET INFO:     train_Exhausted label budget [300]   : 300
# COMET INFO:     train_Exhausted labels [300]         : 300
# COMET INFO:     train_Stream progress [300]          : 300
# COMET INFO:     train_curr_epoch [300]               : (0, 299)
# COMET INFO:     train_joint_goal [300]               : (0.0, 0.6289156626506024)
# COMET INFO:     train_loss [240]                     : (0.0009970975806936622, 0.7050527930259705)
# COMET INFO:     train_turn_inform [300]              : (0.0, 0.8433734939759037)
# COMET INFO:     train_turn_request [300]             : (0.007228915662650603, 0.946987951807229)
# COMET INFO:   Parameters:
# COMET INFO:     al_batch             : 256
# COMET INFO:     batch_size           : 64
# COMET INFO:     comp_batch_size      : 128
# COMET INFO:     demb                 : 400
# COMET INFO:     device               : 1
# COMET INFO:     dexp                 : /content/gdrive/My Drive/Colab Notebooks/exp
# COMET INFO:     dhid                 : 200
# COMET INFO:     dout                 : /content/gdrive/My Drive/Colab Notebooks/exp/vanilla
# COMET INFO:     dropout              : {'emb': 0.2, 'local': 0.2, 'global': 0.2}
# COMET INFO:     epochs               : 50
# COMET INFO:     eval_period          : 1
# COMET INFO:     fff                  : 1
# COMET INFO:     final_epochs         : 50
# COMET INFO:     fit_items            : 512
# COMET INFO:     force_seed           : True
# COMET INFO:     gamma                : 0.75
# COMET INFO:     inference_batch_size : 512
# COMET INFO:     init_threshold       : 0.5
# COMET INFO:     label_budget         : 400
# COMET INFO:     label_timeout        : 10
# COMET INFO:     lr                   : 0.001
# COMET INFO:     model                : glad
# COMET INFO:     nick                 : vanilla
# COMET INFO:     noise_fn             : 1
# COMET INFO:     noise_fp             : 1
# COMET INFO:     num_passes           : 1
# COMET INFO:     optimistic_weighting : 1
# COMET INFO:     rejection_ratio      : 16.0
# COMET INFO:     resume               : 1
# COMET INFO:     sample_mode          : singlepass
# COMET INFO:     seed                 : 2
# COMET INFO:     seed_batch_size      : 64
# COMET INFO:     seed_epochs          : 300
# COMET INFO:     seed_size            : 512
# COMET INFO:     sl_reduction         : 1
# COMET INFO:     stop                 : joint_goal
# COMET INFO:     strategy             : 1
# COMET INFO:     threshold_noise_std  : 0.05
# COMET INFO:     threshold_scaler     : 0.95
# COMET INFO:     threshold_strategy   : fixed
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (32 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     model graph              : 1
# COMET INFO:     os packages              : 1
# COMET INFO: ---------------------------
# COMET INFO: old comet version (3.1.4) detected. current: 3.1.5 please update your comet lib with command: `pip install --no-cache-dir --upgrade comet_ml`
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/ericzhao28/activedialogue/ba2bb8ebf8604ca69d860c727b00a4ab
# Loading Woz dataset.
# Woz: loading split train
# Loaded 2536 turns.
# Loaded 600 dialogues.
# 94 classes
# Woz: loading split dev
# Loaded 830 turns.
# Loaded 200 dialogues.
# 94 classes
# Woz: loading split test
# Loaded 1646 turns.
# Loaded 400 dialogues.
# 94 classes
# dataset sizes: {'train': 600, 'dev': 200, 'test': 400}
# First 10 dataset stream pointers: [1155  796  970  967 1978  897 1975 2332  964  657]
# Seed size: 512
# Pool size: 2024
# loading model from /content/gdrive/My Drive/Colab Notebooks/exp/vanilla/seed2.t7
# Loaded seed.
# loading model from /content/gdrive/My Drive/Colab Notebooks/exp/vanilla/seed2.t7
# Running dev evaluation
# Initial metrics: {'Stream progress': 0.0, 'Exhausted label budget': 0.0, 'Exhausted labels': 0, 'Example label proportion': 0.0, 'turn_inform': 0.8433734939759037, 'turn_request': 0.9421686746987952, 'joint_goal': 0.6289156626506024}
# Running dev evaluation
# Starting fit epoch 0.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8012048192771084, 'turn_request': 0.946987951807229, 'joint_goal': 0.5421686746987951}
# Starting fit epoch 1.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8385542168674699, 'turn_request': 0.9385542168674699, 'joint_goal': 0.6542168674698795}
# Saving best!
# saving model to /content/gdrive/My Drive/Colab Notebooks/exp/vanilla/seed_2_strat_bald_noise_fn_0.0_noise_fp_0.0_num_passes_1_seed_size_512_model_glad_batch_size_64_gamma_0.75_label_budget_400_epochs_502.t7
# Starting fit epoch 2.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8132530120481928, 'turn_request': 0.9421686746987952, 'joint_goal': 0.5771084337349398}
# Starting fit epoch 3.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8409638554216867, 'turn_request': 0.9397590361445783, 'joint_goal': 0.6409638554216868}
# Starting fit epoch 4.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8409638554216867, 'turn_request': 0.9397590361445783, 'joint_goal': 0.6337349397590362}
# Starting fit epoch 5.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8421686746987952, 'turn_request': 0.9433734939759036, 'joint_goal': 0.6469879518072289}
# Starting fit epoch 6.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8506024096385543, 'turn_request': 0.9506024096385542, 'joint_goal': 0.6686746987951807}
# Saving best!
# saving model to /content/gdrive/My Drive/Colab Notebooks/exp/vanilla/seed_2_strat_bald_noise_fn_0.0_noise_fp_0.0_num_passes_1_seed_size_512_model_glad_batch_size_64_gamma_0.75_label_budget_400_epochs_502.t7
# Starting fit epoch 7.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8530120481927711, 'turn_request': 0.9457831325301205, 'joint_goal': 0.6771084337349398}
# Saving best!
# saving model to /content/gdrive/My Drive/Colab Notebooks/exp/vanilla/seed_2_strat_bald_noise_fn_0.0_noise_fp_0.0_num_passes_1_seed_size_512_model_glad_batch_size_64_gamma_0.75_label_budget_400_epochs_502.t7
# Starting fit epoch 8.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8373493975903614, 'turn_request': 0.9397590361445783, 'joint_goal': 0.6433734939759036}
# Starting fit epoch 9.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8385542168674699, 'turn_request': 0.9457831325301205, 'joint_goal': 0.6397590361445783}
# Starting fit epoch 10.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8602409638554217, 'turn_request': 0.944578313253012, 'joint_goal': 0.691566265060241}
# Saving best!
# saving model to /content/gdrive/My Drive/Colab Notebooks/exp/vanilla/seed_2_strat_bald_noise_fn_0.0_noise_fp_0.0_num_passes_1_seed_size_512_model_glad_batch_size_64_gamma_0.75_label_budget_400_epochs_502.t7
# Starting fit epoch 11.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8493975903614458, 'turn_request': 0.9421686746987952, 'joint_goal': 0.6734939759036145}
# Starting fit epoch 12.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8361445783132531, 'turn_request': 0.9397590361445783, 'joint_goal': 0.6397590361445783}
# Starting fit epoch 13.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8530120481927711, 'turn_request': 0.9433734939759036, 'joint_goal': 0.6903614457831325}
# Starting fit epoch 14.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8493975903614458, 'turn_request': 0.944578313253012, 'joint_goal': 0.6759036144578313}
# Starting fit epoch 15.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8554216867469879, 'turn_request': 0.9397590361445783, 'joint_goal': 0.6795180722891566}
# Starting fit epoch 16.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8530120481927711, 'turn_request': 0.9433734939759036, 'joint_goal': 0.6686746987951807}
# Starting fit epoch 17.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8626506024096385, 'turn_request': 0.9397590361445783, 'joint_goal': 0.6987951807228916}
# Saving best!
# saving model to /content/gdrive/My Drive/Colab Notebooks/exp/vanilla/seed_2_strat_bald_noise_fn_0.0_noise_fp_0.0_num_passes_1_seed_size_512_model_glad_batch_size_64_gamma_0.75_label_budget_400_epochs_502.t7
# Starting fit epoch 18.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8542168674698796, 'turn_request': 0.946987951807229, 'joint_goal': 0.6734939759036145}
# Starting fit epoch 19.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8662650602409638, 'turn_request': 0.946987951807229, 'joint_goal': 0.7024096385542169}
# Saving best!
# saving model to /content/gdrive/My Drive/Colab Notebooks/exp/vanilla/seed_2_strat_bald_noise_fn_0.0_noise_fp_0.0_num_passes_1_seed_size_512_model_glad_batch_size_64_gamma_0.75_label_budget_400_epochs_502.t7
# Starting fit epoch 20.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.863855421686747, 'turn_request': 0.9433734939759036, 'joint_goal': 0.6951807228915663}
# Starting fit epoch 21.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8554216867469879, 'turn_request': 0.9397590361445783, 'joint_goal': 0.6710843373493975}
# Starting fit epoch 22.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8614457831325302, 'turn_request': 0.9421686746987952, 'joint_goal': 0.6879518072289157}
# Starting fit epoch 23.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8650602409638555, 'turn_request': 0.9373493975903614, 'joint_goal': 0.6987951807228916}
# Starting fit epoch 24.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8578313253012049, 'turn_request': 0.944578313253012, 'joint_goal': 0.6831325301204819}
# Starting fit epoch 25.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8650602409638555, 'turn_request': 0.944578313253012, 'joint_goal': 0.6975903614457831}
# Starting fit epoch 26.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8626506024096385, 'turn_request': 0.9481927710843373, 'joint_goal': 0.6927710843373494}
# Starting fit epoch 27.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8650602409638555, 'turn_request': 0.9493975903614458, 'joint_goal': 0.691566265060241}
# Starting fit epoch 28.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8626506024096385, 'turn_request': 0.946987951807229, 'joint_goal': 0.6867469879518072}
# Starting fit epoch 29.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8650602409638555, 'turn_request': 0.944578313253012, 'joint_goal': 0.6963855421686747}
# Starting fit epoch 30.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8626506024096385, 'turn_request': 0.946987951807229, 'joint_goal': 0.6975903614457831}
# Starting fit epoch 31.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8662650602409638, 'turn_request': 0.944578313253012, 'joint_goal': 0.7}
# Starting fit epoch 32.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8590361445783132, 'turn_request': 0.9433734939759036, 'joint_goal': 0.6807228915662651}
# Starting fit epoch 33.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8650602409638555, 'turn_request': 0.9433734939759036, 'joint_goal': 0.691566265060241}
# Starting fit epoch 34.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8626506024096385, 'turn_request': 0.9433734939759036, 'joint_goal': 0.6879518072289157}
# Starting fit epoch 35.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8590361445783132, 'turn_request': 0.944578313253012, 'joint_goal': 0.6795180722891566}
# Starting fit epoch 36.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8626506024096385, 'turn_request': 0.9481927710843373, 'joint_goal': 0.6843373493975904}
# Starting fit epoch 37.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8674698795180723, 'turn_request': 0.944578313253012, 'joint_goal': 0.7012048192771084}
# Starting fit epoch 38.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8674698795180723, 'turn_request': 0.944578313253012, 'joint_goal': 0.7048192771084337}
# Saving best!
# saving model to /content/gdrive/My Drive/Colab Notebooks/exp/vanilla/seed_2_strat_bald_noise_fn_0.0_noise_fp_0.0_num_passes_1_seed_size_512_model_glad_batch_size_64_gamma_0.75_label_budget_400_epochs_502.t7
# Starting fit epoch 39.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8674698795180723, 'turn_request': 0.9397590361445783, 'joint_goal': 0.7}
# Starting fit epoch 40.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.863855421686747, 'turn_request': 0.9457831325301205, 'joint_goal': 0.6867469879518072}
# Starting fit epoch 41.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8698795180722891, 'turn_request': 0.9481927710843373, 'joint_goal': 0.7060240963855422}
# Saving best!
# saving model to /content/gdrive/My Drive/Colab Notebooks/exp/vanilla/seed_2_strat_bald_noise_fn_0.0_noise_fp_0.0_num_passes_1_seed_size_512_model_glad_batch_size_64_gamma_0.75_label_budget_400_epochs_502.t7
# Starting fit epoch 42.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8722891566265061, 'turn_request': 0.9493975903614458, 'joint_goal': 0.7132530120481928}
# Saving best!
# saving model to /content/gdrive/My Drive/Colab Notebooks/exp/vanilla/seed_2_strat_bald_noise_fn_0.0_noise_fp_0.0_num_passes_1_seed_size_512_model_glad_batch_size_64_gamma_0.75_label_budget_400_epochs_502.t7
# Starting fit epoch 43.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8650602409638555, 'turn_request': 0.9457831325301205, 'joint_goal': 0.689156626506024}
# Starting fit epoch 44.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8626506024096385, 'turn_request': 0.9506024096385542, 'joint_goal': 0.6963855421686747}
# Starting fit epoch 45.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8686746987951808, 'turn_request': 0.9493975903614458, 'joint_goal': 0.7024096385542169}
# Starting fit epoch 46.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8614457831325302, 'turn_request': 0.9542168674698795, 'joint_goal': 0.6903614457831325}
# Starting fit epoch 47.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8240963855421687, 'turn_request': 0.9542168674698795, 'joint_goal': 0.608433734939759}
# Starting fit epoch 48.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.827710843373494, 'turn_request': 0.9554216867469879, 'joint_goal': 0.6036144578313253}
# Starting fit epoch 49.
# Fitting on 764 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.12648221343873517, 'Exhausted label budget': 0.63, 'Exhausted labels': 252, 'Example label proportion': 0.09936908517350158, 'turn_inform': 0.8518072289156626, 'turn_request': 0.9530120481927711, 'joint_goal': 0.6662650602409639}
# loading model from /content/gdrive/My Drive/Colab Notebooks/exp/vanilla/seed_2_strat_bald_noise_fn_0.0_noise_fp_0.0_num_passes_1_seed_size_512_model_glad_batch_size_64_gamma_0.75_label_budget_400_epochs_502.t7
# Running dev evaluation
# Starting fit epoch 0.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8554216867469879, 'turn_request': 0.9518072289156626, 'joint_goal': 0.6746987951807228}
# Starting fit epoch 1.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8626506024096385, 'turn_request': 0.9481927710843373, 'joint_goal': 0.7060240963855422}
# Starting fit epoch 2.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8349397590361446, 'turn_request': 0.9530120481927711, 'joint_goal': 0.6289156626506024}
# Starting fit epoch 3.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.863855421686747, 'turn_request': 0.946987951807229, 'joint_goal': 0.7060240963855422}
# Starting fit epoch 4.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.7710843373493976, 'turn_request': 0.9518072289156626, 'joint_goal': 0.4891566265060241}
# Starting fit epoch 5.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8253012048192772, 'turn_request': 0.9530120481927711, 'joint_goal': 0.6180722891566265}
# Starting fit epoch 6.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8373493975903614, 'turn_request': 0.9542168674698795, 'joint_goal': 0.6337349397590362}
# Starting fit epoch 7.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8385542168674699, 'turn_request': 0.9542168674698795, 'joint_goal': 0.6253012048192771}
# Starting fit epoch 8.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8506024096385543, 'turn_request': 0.9542168674698795, 'joint_goal': 0.6686746987951807}
# Starting fit epoch 9.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8614457831325302, 'turn_request': 0.9481927710843373, 'joint_goal': 0.6951807228915663}
# Starting fit epoch 10.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8602409638554217, 'turn_request': 0.9578313253012049, 'joint_goal': 0.6831325301204819}
# Starting fit epoch 11.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8722891566265061, 'turn_request': 0.9566265060240964, 'joint_goal': 0.7253012048192771}
# Saving best!
# saving model to /content/gdrive/My Drive/Colab Notebooks/exp/vanilla/seed_2_strat_bald_noise_fn_0.0_noise_fp_0.0_num_passes_1_seed_size_512_model_glad_batch_size_64_gamma_0.75_label_budget_400_epochs_502.t7
# Starting fit epoch 12.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8722891566265061, 'turn_request': 0.9530120481927711, 'joint_goal': 0.7168674698795181}
# Starting fit epoch 13.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8566265060240964, 'turn_request': 0.9518072289156626, 'joint_goal': 0.6759036144578313}
# Starting fit epoch 14.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8686746987951808, 'turn_request': 0.9530120481927711, 'joint_goal': 0.7012048192771084}
# Starting fit epoch 15.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8542168674698796, 'turn_request': 0.9493975903614458, 'joint_goal': 0.672289156626506}
# Starting fit epoch 16.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8686746987951808, 'turn_request': 0.9530120481927711, 'joint_goal': 0.7012048192771084}
# Starting fit epoch 17.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8590361445783132, 'turn_request': 0.9542168674698795, 'joint_goal': 0.6759036144578313}
# Starting fit epoch 18.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8698795180722891, 'turn_request': 0.9542168674698795, 'joint_goal': 0.7048192771084337}
# Starting fit epoch 19.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8590361445783132, 'turn_request': 0.9554216867469879, 'joint_goal': 0.6855421686746987}
# Starting fit epoch 20.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8590361445783132, 'turn_request': 0.9433734939759036, 'joint_goal': 0.6843373493975904}
# Starting fit epoch 21.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8771084337349397, 'turn_request': 0.9578313253012049, 'joint_goal': 0.7349397590361446}
# Saving best!
# saving model to /content/gdrive/My Drive/Colab Notebooks/exp/vanilla/seed_2_strat_bald_noise_fn_0.0_noise_fp_0.0_num_passes_1_seed_size_512_model_glad_batch_size_64_gamma_0.75_label_budget_400_epochs_502.t7
# Starting fit epoch 22.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8662650602409638, 'turn_request': 0.9566265060240964, 'joint_goal': 0.7048192771084337}
# Starting fit epoch 23.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8795180722891566, 'turn_request': 0.9554216867469879, 'joint_goal': 0.7301204819277108}
# Starting fit epoch 24.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8819277108433735, 'turn_request': 0.9554216867469879, 'joint_goal': 0.7397590361445783}
# Saving best!
# saving model to /content/gdrive/My Drive/Colab Notebooks/exp/vanilla/seed_2_strat_bald_noise_fn_0.0_noise_fp_0.0_num_passes_1_seed_size_512_model_glad_batch_size_64_gamma_0.75_label_budget_400_epochs_502.t7
# Starting fit epoch 25.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8674698795180723, 'turn_request': 0.9506024096385542, 'joint_goal': 0.708433734939759}
# Starting fit epoch 26.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8662650602409638, 'turn_request': 0.9554216867469879, 'joint_goal': 0.7036144578313253}
# Starting fit epoch 27.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.863855421686747, 'turn_request': 0.9566265060240964, 'joint_goal': 0.7120481927710843}
# Starting fit epoch 28.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8530120481927711, 'turn_request': 0.9554216867469879, 'joint_goal': 0.6819277108433734}
# Starting fit epoch 29.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.880722891566265, 'turn_request': 0.9566265060240964, 'joint_goal': 0.7385542168674699}
# Starting fit epoch 30.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8722891566265061, 'turn_request': 0.9530120481927711, 'joint_goal': 0.7240963855421687}
# Starting fit epoch 31.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8759036144578313, 'turn_request': 0.9542168674698795, 'joint_goal': 0.7120481927710843}
# Starting fit epoch 32.
# Fitting on 912 datapoints.
# Running dev evaluation
# Epoch metrics: {'Stream progress': 0.25296442687747034, 'Exhausted label budget': 1.0, 'Exhausted labels': 400, 'Example label proportion': 0.15772870662460567, 'turn_inform': 0.8771084337349397, 'turn_request': 0.9542168674698795, 'joint_goal': 0.7204819277108434}
# Starting fit epoch 33.
# Fitting on 912 datapoints.
# Running dev evaluation

# %%
main("--strategy entropy --init_threshold 1.0 --model glad" + shared, not_run)
not_run = False

# %%
main("--strategy aggressive --model glad --al_batch 3000" + shared, not_run)
not_run = False

# %%
main("--strategy passive --model glad --al_batch 3000" + shared, not_run)
not_run = False
